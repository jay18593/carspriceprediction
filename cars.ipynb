# %%
import numpy as np
import pandas as pd
import matplotlib.pylab as plt

# %%
pwd
# Out:
# 'C:\\Users\\Jay Chauhan\\Desktop\\usedcars analysis python project cognitive class\\my python files for the project'

# %%
usedcars=pd.read_csv('automobile.csv')

# %%
usedcars.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...    \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68     9  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19   3.4  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19   3.4   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19   3.4   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
usedcars.head(5)
# Out:
#    3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...    \
# 0  3    ?  alfa-romero  gas  std   two  convertible  rwd  front  88.6  ...
# 1  1    ?  alfa-romero  gas  std   two    hatchback  rwd  front  94.5  ...
# 2  2  164         audi  gas  std  four        sedan  fwd  front  99.8  ...
# 3  2  164         audi  gas  std  four        sedan  4wd  front  99.4  ...
# 4  2    ?         audi  gas  std   two        sedan  fwd  front  99.8  ...
#
#    130  mpfi  3.47  2.68     9  111  5000  21  27  13495
# 0  130  mpfi  3.47  2.68   9.0  111  5000  21  27  16500
# 1  152  mpfi  2.68  3.47   9.0  154  5000  19  26  16500
# 2  109  mpfi  3.19   3.4  10.0  102  5500  24  30  13950
# 3  136  mpfi  3.19   3.4   8.0  115  5500  18  22  17450
# 4  136  mpfi  3.19   3.4   8.5  110  5500  19  25  15250
#
# [5 rows x 26 columns]

# %%
headers=["symboling","normalized-losses","make","fuel-type","aspiration","num-of-doors","body-style","drive-wheels",
         "engine-location","wheel-base","length","width","height","curb-weight","engine-type","num-of-cylinders",
         "engine-size","fuel-system","bore","stroke","compression-ratio","horsepower","peak-rpm","city-mpg","highway-mpg",
         "price"]

# %%
usedcars.columns=headers

# %%
usedcars.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          1                 ?  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2                 ?         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
usedcars.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
usedcars.replace("?",np.nan,inplace=True)

# %%
usedcars.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               NaN  alfa-romero       gas        std          two
# 1          1               NaN  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               NaN         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
usedcars.isnull().sum()
# Out:
# symboling             0
# normalized-losses    40
# make                  0
# fuel-type             0
# aspiration            0
# num-of-doors          2
# body-style            0
# drive-wheels          0
# engine-location       0
# wheel-base            0
# length                0
# width                 0
# height                0
# curb-weight           0
# engine-type           0
# num-of-cylinders      0
# engine-size           0
# fuel-system           0
# bore                  4
# stroke                4
# compression-ratio     0
# horsepower            2
# peak-rpm              2
# city-mpg              0
# highway-mpg           0
# price                 4
# dtype: int64

# %%
avg_norm_loss=usedcars["normalized-losses"].astype("float").mean()

# %%
avg_norm_loss
# Out:
# 122.0

# %%
usedcars["normalized-losses"]=usedcars["normalized-losses"].replace(np.nan,avg_norm_loss)
#or we can use inplcae=True,to change the original
# dataset usedcars["normalized-losses"].replace(np.nana,avg_norm_loss,inplace=True)

# %%
usedcars.head(5)
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3               122  alfa-romero       gas        std          two
# 1          1               122  alfa-romero       gas        std          two
# 2          2               164         audi       gas        std         four
# 3          2               164         audi       gas        std         four
# 4          2               122         audi       gas        std          two
#
#     body-style drive-wheels engine-location  wheel-base  ...    engine-size  \
# 0  convertible          rwd           front        88.6  ...            130
# 1    hatchback          rwd           front        94.5  ...            152
# 2        sedan          fwd           front        99.8  ...            109
# 3        sedan          4wd           front        99.4  ...            136
# 4        sedan          fwd           front        99.8  ...            136
#
# ...

# %%
avg_stroke=usedcars["stroke"].astype("float").mean()

# %%
avg_stroke
# Out:
# 3.258299999999994

# %%
usedcars["stroke"].replace(np.nan,avg_stroke,inplace=True)

# %%
avg_bore=usedcars["bore"].astype("float").mean()

# %%
avg_bore
# Out:
# 3.3290500000000014

# %%
usedcars["bore"].replace(np.nan,avg_bore,inplace=True)

# %%
avg_hp=usedcars["horsepower"].astype("float").mean()

# %%
avg_hp
# Out:
# 104.22277227722772

# %%
usedcars["horsepower"].replace(np.nan,avg_hp,inplace=True)

# %%
avg_peakrpm=usedcars["peak-rpm"].astype("float").mean()

# %%
avg_peakrpm
# Out:
# 5125.990099009901

# %%
usedcars["peak-rpm"].replace(np.nan,avg_peakrpm,inplace=True)

# %%
usedcars["num-of-doors"].value_counts()
#here we use value_counts() method to see how many types of different value counts for each variable we have,
#we will replace null values with the most common variable which occured mpore times in a cell.
# Out:
# four    114
# two      88
# Name: num-of-doors, dtype: int64

# %%
usedcars["num-of-doors"].value_counts().idxmax()
#if we use idxmax() method in the end then it will give you the most occured value of that column.
# Out:
# 'four'

# %%
usedcars["num-of-doors"].replace(np.nan,"four",inplace=True)

# %%
usedcars.dropna(subset=["price"], axis=0, inplace=True)
#axis=0 is for rows.
#here is the end of dealing with missing values, Now we do not have any missing data in our dataset.

# %%
# reset index, because we droped two rows
usedcars.reset_index(drop=True, inplace=True)

# %%
usedcars.dtypes
# Out:
# symboling              int64
# normalized-losses     object
# make                  object
# fuel-type             object
# aspiration            object
# num-of-doors          object
# body-style            object
# drive-wheels          object
# engine-location       object
# wheel-base           float64
# length               float64
# width                float64
# height               float64
# curb-weight            int64
# engine-type           object
# num-of-cylinders      object
# engine-size            int64
# fuel-system           object
# bore                  object
# stroke                object
# compression-ratio    float64
# horsepower            object
# peak-rpm              object
# city-mpg               int64
# highway-mpg            int64
# price                 object
# dtype: object

# %%
#convert data types to proper format
usedcars[["bore","stroke"]]=usedcars[["bore","stroke"]].astype("float")

# %%
usedcars[["normalized-losses"]]=usedcars[["normalized-losses"]].astype("int")
usedcars[["price"]]=usedcars[["price"]].astype("float")
usedcars[["peak-rpm"]]=usedcars[["peak-rpm"]].astype("float")

# %%
usedcars.rename(columns={'highway-mpg':'highway-l/100'},inplace=True)

# %%
usedcars.columns
# Out:
# Index(['symboling', 'normalized-losses', 'make', 'fuel-type', 'aspiration',
#        'num-of-doors', 'body-style', 'drive-wheels', 'engine-location',
#        'wheel-base', 'length', 'width', 'height', 'curb-weight', 'engine-type',
#        'num-of-cylinders', 'engine-size', 'fuel-system', 'bore', 'stroke',
#        'compression-ratio', 'horsepower', 'peak-rpm', 'city-mpg',
#        'highway-l/100', 'price'],
#       dtype='object')

# %%
usedcars["highway-l/100"]=235/usedcars["highway-l/100"]

# %%
usedcars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base   ...     \
# 0          two  convertible          rwd           front        88.6   ...
# 1          two    hatchback          rwd           front        94.5   ...
# 2         four        sedan          fwd           front        99.8   ...
# 3         four        sedan          4wd           front        99.4   ...
# 4          two        sedan          fwd           front        99.8   ...
#
#    engine-size  fuel-system  bore  stroke compression-ratio horsepower  \
# ...

# %%
usedcars["city-l/100"]=235/usedcars["city-mpg"]

# %%
usedcars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0          two  convertible          rwd           front        88.6
# 1          two    hatchback          rwd           front        94.5
# 2         four        sedan          fwd           front        99.8
# 3         four        sedan          4wd           front        99.4
# 4          two        sedan          fwd           front        99.8
#
#       ...      fuel-system  bore  stroke  compression-ratio horsepower  \
# 0     ...             mpfi  3.47    2.68                9.0        111
# ...

# %%
#data normalization: It is a process to convert values of variables in a range of 0 to 1 so while we do analysis,
#or make the model, results doesn"t get skwedor get affected because of their big value range.
usedcars["length"]=usedcars["length"]/usedcars["length"].max()

# %%
usedcars["width"]=usedcars["width"]/usedcars["width"].max()

# %%
usedcars["height"]=usedcars["height"]/usedcars["height"].max()

# %%
usedcars["horsepower"]=usedcars["horsepower"].astype(int, copy=True)

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
plt.pyplot.hist(usedcars["horsepower"])

#set x/y lables and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
bins=np.linspace(min(usedcars["horsepower"]),max(usedcars["horsepower"]),4)
bins
# Out:
# array([ 48.        , 119.33333333, 190.66666667, 262.        ])

# %%
group_names=['low','medium','high']

# %%
#now we need cut function...
usedcars["horsepower-binned"]=pd.cut(usedcars["horsepower"], bins, labels=group_names, include_lowest=True)
usedcars[["horsepower","horsepower-binned"]].head(20)
# Out:
#     horsepower horsepower-binned
# 0          111               low
# 1          154            medium
# 2          102               low
# 3          115               low
# 4          110               low
# 5          110               low
# 6          110               low
# 7          140            medium
# 8          101               low
# 9          101               low
# 10         121            medium
# 11         121            medium
# 12         121            medium
# 13         182            medium
# 14         182            medium
# 15         182            medium
# 16          48               low
# 17          70               low
# 18          70               low
# 19          68               low

# %%
usedcars["horsepower-binned"].value_counts()
# Out:
# low       152
# medium     43
# high        5
# Name: horsepower-binned, dtype: int64

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, usedcars["horsepower-binned"].value_counts())

# set x/y labels and plot title
plt.pyplot.xlabel("horsepower")
plt.pyplot.ylabel("count")
plt.pyplot.title("horsepower bins")
# Out:
# Text(0.5, 1.0, 'horsepower bins')

# %%
usedcars.head()
# Out:
#    symboling  normalized-losses         make fuel-type aspiration  \
# 0          3                122  alfa-romero       gas        std
# 1          1                122  alfa-romero       gas        std
# 2          2                164         audi       gas        std
# 3          2                164         audi       gas        std
# 4          2                122         audi       gas        std
#
#   num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0          two  convertible          rwd           front        88.6
# 1          two    hatchback          rwd           front        94.5
# 2         four        sedan          fwd           front        99.8
# 3         four        sedan          4wd           front        99.4
# 4          two        sedan          fwd           front        99.8
#
#          ...          bore  stroke  compression-ratio  horsepower peak-rpm  \
# ...

# %%
#now we need dummy variables for fuel-type column bcz regression analysis can be done with numeric values only so we need to
#convert fuel-type column in to dummy variable.
dummy_variable_1=pd.get_dummies(usedcars["fuel-type"])
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
dummy_variable_1.rename(columns={'fuel-type-diesel':'gas','fuel-type-diesel':'diesel'}, inplace=True)
dummy_variable_1.head()
# Out:
#    diesel  gas
# 0       0    1
# 1       0    1
# 2       0    1
# 3       0    1
# 4       0    1

# %%
# merge data frame "df" and "dummy_variable_1"
usedcars = pd.concat([usedcars, dummy_variable_1], axis=1)
# drop original column "fuel-type" from "df"
usedcars.drop("fuel-type", axis=1, inplace=True)

# %%
dummy_variable_2=pd.get_dummies(usedcars["aspiration"])
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
dummy_variable_2.rename(columns={'aspiration':'std','aspiration':'turbo'}, inplace=True)
dummy_variable_2.head()
# Out:
#    std  turbo
# 0    1      0
# 1    1      0
# 2    1      0
# 3    1      0
# 4    1      0

# %%
usedcars = pd.concat([usedcars,dummy_variable_2], axis=1)

# %%
usedcars.drop("aspiration", axis=1, inplace=True)

# %%
usedcars.to_csv('clean_usedcars.csv')
